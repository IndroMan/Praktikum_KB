# %% [markdown]
# <h1> Indro Dwi Saputro <br>
#     2009106099 <br>
#     POSTTEST 3

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("data-item.csv")

# %%
df
# Out:
#           itemId                 category  \
# 0      100002528  beli-harddisk-eksternal
# 1      100003785  beli-harddisk-eksternal
# 2      100004132  beli-harddisk-eksternal
# 3      100004505  beli-harddisk-eksternal
# 4      100005037  beli-harddisk-eksternal
# ...          ...                      ...
# 10937    9467887    shop-televisi-digital
# 10938    9467898    shop-televisi-digital
# 10939    9467899    shop-televisi-digital
# 10940    9548087    shop-televisi-digital
# 10941    9548767    shop-televisi-digital
#
#                                                     name brandName  \
# 0      TOSHIBA Smart HD LED TV 32" - 32L5650VJ Free B...   Toshiba
# 1      TOSHIBA Full HD Smart LED TV 40" - 40L5650VJ -...   Toshiba
# 2       Samsung 40 Inch Full HD Flat LED Digital TV 4...        LG
# 3              Sharp HD LED TV 24" - LC-24LE175I - Hitam     Sharp
# 4      Lenovo Ideapad 130-15AST LAPTOP MULTIMEDIA I A...    Lenovo
# ...

# %% [markdown]
# <h3> Menggunakan Visualisasi Bar <br>
#     Disini saya menampilkan data atribut kategori dan totalReviews <br>
#     Untuk Melihat berapa banyak review pada kategori tersebut

# %%
x = df[('category')]
y = df[('totalReviews')]

# %%
plt.barh(x, y, align="edge")
plt.title("Total Review")
plt.xlabel("Jumlah")
plt.ylabel("Kategori")
plt.show()

# %% [markdown]
# <h3> Visualisasi selanjutnya saya menggunakan grafik pie <br>
#     disini saya akan memperlihatkan banyak nya review di setiap kategori

# %%
df['category'].value_counts()

# %%
labels = df['category'].value_counts().rename_axis('category').reset_index(name='Jumlah')
labels
# Out:
#                   category  Jumlah
# 0  beli-harddisk-eksternal    4422
# 1        jual-flash-drives    3318
# 2            beli-smart-tv    1290
# 3    shop-televisi-digital    1211
# 4              beli-laptop     701

# %%
plt.figure(figsize=(8,8), dpi=200)
plt.pie(df['category'].value_counts(), labels=labels['category'], autopct='%.1f%%', startangle=90)
plt.show()

# %% [markdown]
# <h3> Grafik Scatter Plot <br>
#     diagram grafis yang dibangun dari dua sumbu X dan Y (variabel X dan variabel Y). Scatter plot menunjukan hubungan antara dua variabel.
#
# Implementasi grafik Scatter Plot sebagai berikut

# %%
sns.scatterplot(data = df, x='category', y = 'totalReviews')
plt.title("Persebaran data ukuran totalReviews dengan category yang beda")
plt.show()

# %% [markdown]
# <h3> Grafik Heatmap <br>
#     grafik ini digunakan untuk melihat Korelasi antar atribut.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.heatmap(df.corr(), cmap='BuPu')
ax.set_title('Korelasi antar atribut pada dataset')
plt.show()
# Out:
# C:\Users\WINDOWS\AppData\Local\Temp\ipykernel_660\436570652.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), cmap='BuPu')

# %% [markdown]
#  <h5>Dari tampilan grafik diatas menyatakan <br>
# tidak ada korelasi yang baik antar atribut yang berbeda
